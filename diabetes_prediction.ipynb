# %% [markdown]
# ##Diabates Prediction
# ###Training a Suport Vector Machine

# %% [markdown]
# Importing libraries

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# ###Data Collection and Analysis

# %%
df = pd.read_csv('/content/drive/MyDrive/datasets/diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
#number of rows and columns in the dataframe
df.shape
# Out:
# (768, 9)

# %%
#statistical measure of the data
df.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
# 0 means non diabetic, and 1 means diabetic
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  ...  DiabetesPedigreeFunction        Age
# Outcome                           ...
# 0           3.298000  109.980000  ...                  0.429734  31.190000
# 1           4.865672  141.257463  ...                  0.550500  37.067164
#
# [2 rows x 8 columns]

# %%
labels = df['Outcome']
data = df.drop(columns = 'Outcome', axis = 1)

# %%
print(type(labels), '\n', type(data))
# Out:
# <class 'pandas.core.series.Series'>
#  <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ###Data Standardization

# %%
scaler = StandardScaler()

# %%
scaler.fit(data)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
data = scaler.transform(data)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(data, labels, test_size = 0.2, stratify = labels, random_state = 2)

# %%
print(data.shape, X_test.shape, X_train.shape)
# Out:
# (768, 8) (154, 8) (614, 8)

# %% [markdown]
# ###Training the model

# %%
model = svm.SVC(kernel = 'linear')

# %%
model.fit(X_train, Y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# ###Model evaluation

# %%
prediction = model.predict(X_test)
pred_accuracy = accuracy_score(prediction, Y_test)
print("Accuracy score: ", pred_accuracy)
# Out:
# Accuracy score:  0.7727272727272727

# %% [markdown]
# ###Building a predictive system

# %%
# taking a sample from dataset: 1,189,60,23,846,30.1,0.398,59 -> 1 = diabetics
input_data = (1,189,60,23,846,30.1,0.398,59)

#input_data to numpy array and reshape it
input_data = np.asarray(input_data).reshape(1, -1)

#standardize the input data
input_data = scaler.transform(input_data)
print(input_data)

pred = model.predict(input_data)
if pred[0] == 0:
  print('The person isn\'t diabetics')
else:
  print ('The person is diabetics')
# Out:
# [[-0.84488505  2.13150675 -0.47073225  0.15453319  6.65283938 -0.24020459
#   -0.2231152   2.19178518]]
# The person is diabetics

# %% [markdown]
# ##Referências
# ####Dataset PIMA Indians Diabetes Database at Kaggle <https://www.kaggle.com/uciml/pima-indians-diabetes-database>
#
# ####Tutorial Video: Project 2: Diabetes Prediction using Machine Learning with Python | End To End Python ML Project <https://www.youtube.com/watch?v=xUE7SjVx9bQ>
